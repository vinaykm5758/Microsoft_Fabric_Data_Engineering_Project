# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# StatementMeta(, ef261343-55c2-4ac5-bb21-94d62293131d, 27, Finished, Available)

# %%
df_Address=( spark.\
     read.\
     options(inferSchema='True',
             header='True',
             delimiter=',',
             encoding='UTF-8',
             ignoreLeadingWhiteSpace='True',
             ignoreTrailingWhiteSpace='True')\
     .parquet('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/raw/Address.parquet')
    )
	
	
df_Customer=( spark.\
     read.\
     options(inferSchema='True',
             header='True',
             delimiter=',',
             encoding='UTF-8',
             ignoreLeadingWhiteSpace='True',
             ignoreTrailingWhiteSpace='True')\
     .parquet('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/raw/Customer.parquet')
    )

df_CustomerAddress=( spark.\
     read.\
     options(inferSchema='True',
             header='True',
             delimiter=',',
             encoding='UTF-8',
             ignoreLeadingWhiteSpace='True',
             ignoreTrailingWhiteSpace='True')\
     .parquet('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/raw/CustomerAddress.parquet')
    )

df_Product=( spark.\
     read.\
     options(inferSchema='True',
             header='True',
             delimiter=',',
             encoding='UTF-8',
             ignoreLeadingWhiteSpace='True',
             ignoreTrailingWhiteSpace='True')\
     .parquet('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/raw/Product.parquet')
    )

df_ProductCategory=( spark.\
     read.\
     options(inferSchema='True',
             header='True',
             delimiter=',',
             encoding='UTF-8',
             ignoreLeadingWhiteSpace='True',
             ignoreTrailingWhiteSpace='True')\
     .parquet('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/raw/ProductCategory.parquet')
    )

df_ProductDescription=( spark.\
     read.\
     options(inferSchema='True',
             header='True',
             delimiter=',',
             encoding='UTF-8',
             ignoreLeadingWhiteSpace='True',
             ignoreTrailingWhiteSpace='True')\
     .parquet('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/raw/ProductDescription.parquet')
    )

df_ProductModel=( spark.\
     read.\
     options(inferSchema='True',
             header='True',
             delimiter=',',
             encoding='UTF-8',
             ignoreLeadingWhiteSpace='True',
             ignoreTrailingWhiteSpace='True')\
     .parquet('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/raw/ProductModel.parquet')
    )

df_ProductModelProductDescription=( spark.\
     read.\
     options(inferSchema='True',
             header='True',
             delimiter=',',
             encoding='UTF-8',
             ignoreLeadingWhiteSpace='True',
             ignoreTrailingWhiteSpace='True')\
     .parquet('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/raw/ProductModelProductDescription.parquet')
    )

df_SalesOrderDetail=( spark.\
     read.\
     options(inferSchema='True',
             header='True',
             delimiter=',',
             encoding='UTF-8',
             ignoreLeadingWhiteSpace='True',
             ignoreTrailingWhiteSpace='True')\
     .parquet('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/raw/SalesOrderDetail.parquet')
    )

df_SalesOrderHeader=( spark.\
     read.\
     options(inferSchema='True',
             header='True',
             delimiter=',',
             encoding='UTF-8',
             ignoreLeadingWhiteSpace='True',
             ignoreTrailingWhiteSpace='True')\
     .parquet('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/raw/SalesOrderHeader.parquet')
    )
# Out:
# StatementMeta(, ef261343-55c2-4ac5-bb21-94d62293131d, 24, Finished, Available)

# %%
# df_Address
# df_Customer
# df_CustomerAddress
# df_Product
# df_ProductCategory
# df_ProductDescription
# df_ProductModel
# df_ProductModelProductDescription
# df_SalesOrderDetail
# df_SalesOrderHeader

df_Address.show(5,truncate=False)
# Out:
# StatementMeta(, ef261343-55c2-4ac5-bb21-94d62293131d, 29, Finished, Available)
# +---------+-------------------+------------+--------+-------------+-------------+----------+------------------------------------+-------------------+
# |AddressID|AddressLine1       |AddressLine2|City    |StateProvince|CountryRegion|PostalCode|rowguid                             |ModifiedDate       |
# +---------+-------------------+------------+--------+-------------+-------------+----------+------------------------------------+-------------------+
# |9        |8713 Yosemite Ct.  |null        |Bothell |Washington   |United States|98011     |268af621-76d7-4c78-9441-144fd139821a|2006-07-01 00:00:00|
# |11       |1318 Lasalle Street|null        |Bothell |Washington   |United States|98011     |981b3303-aca2-49c7-9a96-fb670785b269|2007-04-01 00:00:00|
# |25       |9178 Jumping St.   |null        |Dallas  |Texas        |United States|75201     |c8df3bd9-48f0-4654-a8dd-14a67a84d3c6|2006-09-01 00:00:00|
# ...

# %%
df_Product=df_Product.withColumn("ModifiedDate",date_format(from_utc_timestamp(df_Product["ModifiedDate"].cast(TimestampType() ),"UTC"),"yyyy-MM-dd"))\
.withColumn("SellEndDate",date_format(from_utc_timestamp(df_Product["SellEndDate"].cast(TimestampType() ),"UTC"),"yyyy-MM-dd"))\
.withColumn("SellStartDate",date_format(from_utc_timestamp(df_Product["SellStartDate"].cast(TimestampType() ),"UTC"),"yyyy-MM-dd"))
# Out:
# StatementMeta(, ef261343-55c2-4ac5-bb21-94d62293131d, 33, Finished, Available)

# %%
df_Address=df_Address.withColumn("ModifiedDate",date_format(from_utc_timestamp(df_Address["ModifiedDate"].cast(TimestampType() ),"UTC"),"yyyy-MM-dd"))

df_Customer=df_Customer.withColumn("ModifiedDate",date_format(from_utc_timestamp(df_Customer["ModifiedDate"].cast(TimestampType() ),"UTC"),"yyyy-MM-dd"))
df_CustomerAddress=df_CustomerAddress.withColumn("ModifiedDate",date_format(from_utc_timestamp(df_CustomerAddress["ModifiedDate"].cast(TimestampType() ),"UTC"),"yyyy-MM-dd"))

df_Product=df_Product.withColumn("ModifiedDate",date_format(from_utc_timestamp(df_Product["ModifiedDate"].cast(TimestampType() ),"UTC"),"yyyy-MM-dd"))\
.withColumn("SellEndDate",date_format(from_utc_timestamp(df_Product["SellEndDate"].cast(TimestampType() ),"UTC"),"yyyy-MM-dd"))\
.withColumn("SellStartDate",date_format(from_utc_timestamp(df_Product["SellStartDate"].cast(TimestampType() ),"UTC"),"yyyy-MM-dd"))

df_ProductCategory=df_ProductCategory.withColumn("ModifiedDate",date_format(from_utc_timestamp(df_ProductCategory["ModifiedDate"].cast(TimestampType() ),"UTC"),"yyyy-MM-dd"))

df_ProductDescription=df_ProductDescription.withColumn("ModifiedDate",date_format(from_utc_timestamp(df_ProductDescription["ModifiedDate"].cast(TimestampType() ),"UTC"),"yyyy-MM-dd"))

df_SalesOrderDetail=df_SalesOrderDetail.withColumn("ModifiedDate",date_format(from_utc_timestamp(df_SalesOrderDetail["ModifiedDate"].cast(TimestampType() ),"UTC"),"yyyy-MM-dd"))


df_SalesOrderHeader=df_SalesOrderHeader.withColumn("ModifiedDate",date_format(from_utc_timestamp(df_SalesOrderHeader["ModifiedDate"].cast(TimestampType() ),"UTC"),"yyyy-MM-dd"))
# Out:
# StatementMeta(, ef261343-55c2-4ac5-bb21-94d62293131d, 34, Finished, Available)

# %%
df_Address.show(5,truncate=False)
# Out:
# StatementMeta(, ef261343-55c2-4ac5-bb21-94d62293131d, 31, Finished, Available)
# +---------+-------------------+------------+--------+-------------+-------------+----------+------------------------------------+------------+
# |AddressID|AddressLine1       |AddressLine2|City    |StateProvince|CountryRegion|PostalCode|rowguid                             |ModifiedDate|
# +---------+-------------------+------------+--------+-------------+-------------+----------+------------------------------------+------------+
# |9        |8713 Yosemite Ct.  |null        |Bothell |Washington   |United States|98011     |268af621-76d7-4c78-9441-144fd139821a|2006-07-01  |
# |11       |1318 Lasalle Street|null        |Bothell |Washington   |United States|98011     |981b3303-aca2-49c7-9a96-fb670785b269|2007-04-01  |
# |25       |9178 Jumping St.   |null        |Dallas  |Texas        |United States|75201     |c8df3bd9-48f0-4654-a8dd-14a67a84d3c6|2006-09-01  |
# ...

# %%
## Write the data into DELTA TABLE FORMAT



# df_Address
# df_Customer
# df_CustomerAddress
# df_Product
# df_ProductCategory
# df_ProductDescription
# df_ProductModel
# df_ProductModelProductDescription
# df_SalesOrderDetail
# df_SalesOrderHeader


address_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/address/'
df_Address.write.format('delta').mode('overwrite').save(address_path)

customer_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/customer'
df_Customer.write.format('delta').mode('overwrite').save(customer_path)

customeraddress_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/customeraddress/'
df_CustomerAddress.write.format('delta').mode('overwrite').save(customeraddress_path)

product_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/product/'
df_Product.write.format('delta').mode('overwrite').save(product_path)

productcategory_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/productcategory/'
df_ProductCategory.write.format('delta').mode('overwrite').save(productcategory_path)

productdescription_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/productdescription/'
df_ProductDescription.write.format('delta').mode('overwrite').save(productdescription_path)

productmodel_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/productmodel/'
df_ProductModel.write.format('delta').mode('overwrite').save(productmodel_path)

productmodelproductdescription_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/productmodelproductdescription/'
df_ProductModelProductDescription.write.format('delta').mode('overwrite').save(productmodelproductdescription_path)

salesorderdetail_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/salesorderdetail/'
df_SalesOrderDetail.write.format('delta').mode('overwrite').save(salesorderdetail_path)

salesorderheader_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/salesorderheader/'
df_SalesOrderHeader.write.format('delta').mode('overwrite').save(salesorderheader_path)
# Out:
# StatementMeta(, ef261343-55c2-4ac5-bb21-94d62293131d, 39, Finished, Available)

# %%
## Conformed data testing

# df_add_1=( spark.\
#      read.\
#      options(inferSchema='True',
#              header='True',
#              delimiter=',',
#              encoding='UTF-8',
#              ignoreLeadingWhiteSpace='True',
#              ignoreTrailingWhiteSpace='True')\
#      .parquet('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/address/')
#     )
# Out:
# StatementMeta(, ef261343-55c2-4ac5-bb21-94d62293131d, 41, Finished, Available)

# %%
# Conformed DETLA FILES into DataFrames

# %%
# CONFORMED DELTA FORMAT FILES

df_delta_conformed_address=spark.read.format('delta').load('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/address/')
df_delta_conformed_customer=spark.read.format('delta').load('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/customer/')
df_delta_conformed_customeraddress=spark.read.format('delta').load('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/customeraddress/')
df_delta_conformed_product=spark.read.format('delta').load('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/product/')
df_delta_conformed_productcategory=spark.read.format('delta').load('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/productcategory/')
df_delta_conformed_productdescription=spark.read.format('delta').load('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/productdescription/')
df_delta_conformed_productmodel=spark.read.format('delta').load('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/productmodel/')
df_delta_conformed_productmodelproductdescription=spark.read.format('delta').load('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/productmodelproductdescription/')
df_delta_conformed_salesorderdetail=spark.read.format('delta').load('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/salesorderdetail/')
df_delta_conformed_salesorderheader=spark.read.format('delta').load('abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/conformed/salesorderheader/')
# Out:
# StatementMeta(, ef261343-55c2-4ac5-bb21-94d62293131d, 48, Finished, Available)

# %%
df_delta_conformed_address.show(5,truncate=False)
# Out:
# StatementMeta(, ef261343-55c2-4ac5-bb21-94d62293131d, 49, Finished, Available)
# +---------+-----------------------------+--------------+---------------+-------------+--------------+----------+------------------------------------+------------+
# |AddressID|AddressLine1                 |AddressLine2  |City           |StateProvince|CountryRegion |PostalCode|rowguid                             |ModifiedDate|
# +---------+-----------------------------+--------------+---------------+-------------+--------------+----------+------------------------------------+------------+
# |635      |93-2501, Blackfriars Road,   |null          |London         |England      |United Kingdom|SE1 8HL   |00e75f99-488c-462d-a0bc-ac3c08a9db77|2006-09-01  |
# |636      |Science Park South, Birchwood|Stanford House|Warrington     |England      |United Kingdom|WA3 7BH   |c0fc2d5b-88e7-4b60-8447-bb3522bd79e5|2007-07-01  |
# ...

# %%
# df_delta_conformed_address
# df_delta_conformed_customer
# df_delta_conformed_customeraddress
# df_delta_conformed_product
# df_delta_conformed_productcategory
# df_delta_conformed_productdescription
# df_delta_conformed_productmodel
# df_delta_conformed_productmodelproductdescription
# df_delta_conformed_salesorderdetail
# df_delta_conformed_salesorderheader

# Adding Current Timestamp 

df_delta_purpose_built_address=df_delta_conformed_address.withColumn('DateTimeLoaded',current_timestamp())
df_delta_purpose_built_customer=df_delta_conformed_customer.withColumn('DateTimeLoaded',current_timestamp())
df_delta_purpose_built_customeraddress=df_delta_conformed_customeraddress.withColumn('DateTimeLoaded',current_timestamp())
df_delta_purpose_built_product=df_delta_conformed_product.withColumn('DateTimeLoaded',current_timestamp())
df_delta_purpose_built_productcategory=df_delta_conformed_productcategory.withColumn('DateTimeLoaded',current_timestamp())
df_delta_purpose_built_productdescription=df_delta_conformed_productdescription.withColumn('DateTimeLoaded',current_timestamp())
df_delta_purpose_built_productmodel=df_delta_conformed_productmodel.withColumn('DateTimeLoaded',current_timestamp())
df_delta_purpose_built_productmodelproductdescription=df_delta_conformed_productmodelproductdescription.withColumn('DateTimeLoaded',current_timestamp())
df_delta_purpose_built_salesorderdetail=df_delta_conformed_salesorderdetail.withColumn('DateTimeLoaded',current_timestamp())
df_delta_purpose_built_salesorderheader=df_delta_conformed_salesorderheader.withColumn('DateTimeLoaded',current_timestamp())
# Out:
# StatementMeta(, ef261343-55c2-4ac5-bb21-94d62293131d, 57, Finished, Available)

# %%
df_delta_purpose_built_address.show(5,truncate=False)
# Out:
# StatementMeta(, ef261343-55c2-4ac5-bb21-94d62293131d, 58, Finished, Available)
# +---------+-----------------------------+--------------+---------------+-------------+--------------+----------+------------------------------------+------------+-----------------------+
# |AddressID|AddressLine1                 |AddressLine2  |City           |StateProvince|CountryRegion |PostalCode|rowguid                             |ModifiedDate|DateTimeLoaded         |
# +---------+-----------------------------+--------------+---------------+-------------+--------------+----------+------------------------------------+------------+-----------------------+
# |635      |93-2501, Blackfriars Road,   |null          |London         |England      |United Kingdom|SE1 8HL   |00e75f99-488c-462d-a0bc-ac3c08a9db77|2006-09-01  |2023-09-03 01:32:59.069|
# ...

# %%
## Writing intp Purpose Built Layer

address_pb_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/purpose_built/address/'
df_delta_purpose_built_address.write.format('delta').mode('overwrite').save(address_pb_path)

customer_pb_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/purpose_built/customer'
df_delta_purpose_built_customer.write.format('delta').mode('overwrite').save(customer_pb_path)

customeraddress_pb_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/purpose_built/customeraddress/'
df_delta_purpose_built_customeraddress.write.format('delta').mode('overwrite').save(customeraddress_pb_path)

product_pb_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/purpose_built/product/'
df_delta_purpose_built_product.write.format('delta').mode('overwrite').save(product_pb_path)

productcategory_pb_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/purpose_built/productcategory/'
df_delta_purpose_built_productcategory.write.format('delta').mode('overwrite').save(productcategory_pb_path)

productdescription_pb_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/purpose_built/productdescription/'
df_delta_purpose_built_productdescription.write.format('delta').mode('overwrite').save(productdescription_pb_path)

productmodel_pb_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/purpose_built/productmodel/'
df_delta_purpose_built_productmodel.write.format('delta').mode('overwrite').save(productmodel_pb_path)

productmodelproductdescription_pb_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/purpose_built/productmodelproductdescription/'
df_delta_purpose_built_productmodelproductdescription.write.format('delta').mode('overwrite').save(productmodelproductdescription_pb_path)

salesorderdetail_pb_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/purpose_built/salesorderdetail/'
df_delta_purpose_built_salesorderdetail.write.format('delta').mode('overwrite').save(salesorderdetail_pb_path)

salesorderheader_pb_path='abfss://df447167-27d1-4f22-8b74-bf541c33a66b@onelake.dfs.fabric.microsoft.com/b09d0198-c53c-4792-85a8-e24f7558b84e/Files/purpose_built/salesorderheader/'
df_delta_purpose_built_salesorderheader.write.format('delta').mode('overwrite').save(salesorderheader_pb_path)
# Out:
# StatementMeta(, ef261343-55c2-4ac5-bb21-94d62293131d, 59, Finished, Available)
